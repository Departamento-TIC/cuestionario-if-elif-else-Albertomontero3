# %% [markdown]
# <a href="https://colab.research.google.com/github/Departamento-TIC/cuestionario-if-elif-else-Albertomontero3/blob/main/Cuestionario(if_elif_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 3: Créate un Cuestionario [Programar Juegos Arcade con Python y Pygame](http://programarcadegames.com/index.php)
#
#
# #Descripción
# Estas son las características que debe tener tu cuestionario:
#
#
# 1.   Créalo con cinco o más preguntas. Puedes preguntar cosas que requieran
# *   un número como respuesta (por ejemplo; ¿Cuánto es 1+1?)
# *   texto (Por ejemplo; ¿Cuál es el apellido de Harry Potter?)
# *   una selección (¿Cuál de estas opciones son las correctas A, B, o C?)
#
# 2.   Si permites que el usuario introduzca respuestas no numéricas, piensa y cubre las distintas formas en que podría contestar. Por ejemplo, si la respuesta es “a”, sería aceptable también “A”? Échale un vistazo a la Sección 3.6 para que recuerdes cómo conseguir esto.
#
# 3. Debes permitir que el usuario sepa que ha acertado con la respuesta correcta. Imprime un mensaje basado en esa respuesta.
# 4. Debes llevar la cuenta del número de respuestas acertadas.
# 5. Al final del programa, deberás mostrar el porcentaje de respuestas contestadas correctamente por el usuario.
#
# #Ejemplo de ejecución
#
# ```
# ¡A jugar!
#
# ¿De cuántos libros consta la serie de Harry Potter? 7
# Correcto!
#
# ¿Cuánto es 3*(2-1)? 3
# Correcto!
#
# ¿Cuánto es 3*2-1? 5
# Correcto!
#
# ¿Quién canta Black Horse and the Cherry Tree?
# 1. Kelly Clarkson
# 2. K.T. Tunstall
# 3. Hillary Duff
# 4. Bon Jovi
# ? 2
# Correcto!
#
# ¿Qué personaje aparece en el billete de un dólar?
# 1. George Washington
# 2. Abraham Lincoln
# 3. John Adams
# 4. Thomas Jefferson
# ? 2
# No.
#
# Mis felicitaciones, has conseguido 4 respuestas correctas!
# Eso es una puntuación del 80 por ciento.
# ```

# %%
print ("¡¡A jugar!!")
contador = 0

pregunta1 = input ("como se llama el compañero de spyderman en el segundo videojuego")
print("A Bob esponja)
print("B Miles Morales")
print("C Capitán Garfio")

if:
  pregunta1 == "B Miles Morales"

print = ("correcto")
contador += 1
else:
   print "incorrecto es miles morales"

pregunta2 = input ("cuanto es 45-20")
if:
  pregunta2 print == "25"

  print = ("correcto")
contador += 1
else:
      print "incorrecto es 25"

pregunta3 = input ("Como se llama el jugador con mas balones de oro")
print("A Cristiano Ronaldo")
print("B Lionel Messi")
print("C Caye Quintana")

if:
  pregunta3 == "B Lionel Messi"
  print ("correcto")
  contador +=1
else:
      print "incorrecto es Lionel Messi"

pregunta4 = input ("cuanto es 10*5")
if:
  pregunta4 == "50"
  print ("correcto")
  contador += 1
else:
    print "incorrecto es 50"

pregunta5 = input ("como se llama el mejor profesor del mundo")
print("luis hernandez")
print("manuel fernandez")
print("antonio rodriguez")
if:
  pregunta3 == "antonio rodriguez"
